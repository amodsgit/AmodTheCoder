# %% [markdown]
# <a href="https://colab.research.google.com/github/amodsgit/AmodTheCoder/blob/main/HairChat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -qU \
  tiktoken==0.4.0 \
  openai==0.27.7 \
  langchain==0.0.179 \
  pinecone-client==2.2.1 \
  datasets==2.13.1
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 32.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 7.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 907.7/907.7 kB 44.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.2/177.2 kB 17.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.2/486.2 kB 30.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 9.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 kB 14.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 10.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 17.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 11.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 23.0 MB/s eta 0:00:00
# ...

# %%
from datasets import load_dataset

data = load_dataset("Amod/hair_medical_sit", split='train')
data
# Out:
# ...
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset json downloaded and prepared to /root/.cache/huggingface/datasets/Amod___json/Amod--hair_medical_sit-6bcd99466c36287a/0.0.0/8bb11242116d547c741b2e8a1f18598ffdd40a1d4f2a2872c7a28b697434bc96. Subsequent calls will reuse this data.
# Dataset({
#     features: [' Severity of Disease', 'Hair Disease', 'Duration', 'Medication Description', 'Disease Description', 'Side Effects', 'Medication', 'Symptoms'],
#     num_rows: 91
# })

# %%
data[5] # sanmple of a data record
# Out:
# {' Severity of Disease': 'Moderate to severe',
#  'Hair Disease': 'Alopecia Areata',
#  'Duration': '16 weeks',
#  'Medication Description': 'Yet another formulation of clobetasol propionate, the lotion can be particularly useful for larger body areas and may provide a cooling effect upon application.',
#  'Disease Description': 'Alopecia areata is an autoimmune disease where the immune system attacks hair follicles, resulting in hair loss. Hair loss usually occurs in small, round patches on the scalp, but can occur anywhere on the body.',
#  'Side Effects': 'Skin rash, Burning sensation, Itching',
#  'Medication': 'Clobetasol propionate lotion',
#  'Symptoms': 'Patchy hair loss, often on the scalp. The patches are usually several centimeters or less. Hair loss might also occur on other parts of the body.'}

# %%
import tiktoken

tiktoken.encoding_for_model('gpt-3.5-turbo')
# Out:
# <Encoding 'cl100k_base'>

# %%
import tiktoken

tokenizer = tiktoken.get_encoding('cl100k_base')

# create the length function
def tiktoken_len(text):
    tokens = tokenizer.encode(
        text,
        disallowed_special=()
    )
    return len(tokens)

# %%
tiktoken_len(' '.join(data[45].values()))
# Out:
# 135
